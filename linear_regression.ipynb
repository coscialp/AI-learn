# %%
from dataset import load_dataset
from linear_model import REGRESSOR, CLASSIFIER, LinearRegression
from sklearn.model_selection import train_test_split

# %%
dataset = load_dataset('data.csv', 'prices', type=REGRESSOR)

X = dataset.data
y = dataset.target

# %%
model = LinearRegression(1000, 0.01, normalize=True)
model.fit(X, y)

# %%
model.display_train()

# %%
X = (X - X.mean()) / X.std()
model.score(X, y)
# Out:
# 0.723562579350236

# %%
from sklearn.datasets import make_blobs
from preprocessing import one_hot
from linear_model import LogisticRegression, SGDClassifier

X, y = make_blobs(n_samples=1500, n_features=5, centers=2, random_state=3)
y = y.reshape(y.shape[0], 1)
y_onehot = one_hot(y)
model = SGDClassifier(n_iter=1000, learning_rate=0.1, normalize=True, multi_class=False)
model.fit(X, y)
print(model.score(X, y))
model.display_train()
# Out:
# Unable to start Kernel 'Python 3.9.10 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from sklearn.datasets import make_circles, make_blobs, make_classification
import matplotlib.pyplot as plt

X, y = make_circles(n_samples=100, noise=0.1, factor=0.5)
# X, y = make_blobs(n_samples=1000, n_features=3, centers=2)
X = X.T
y = y.reshape((1, y.shape[0]))

print(X.shape)
print(y.shape)


plt.scatter(X[0, :], X[1, :], c=y)
plt.show()
# Out:
# (2, 100)
# (1, 100)

# %%
from neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

model = MLPClassifier((100, 100, 100), n_iter=10000)

model.fit(X, y)

y_test = model.predict(X)

print(accuracy_score(y_test, y))
for epoch, loss, val_loss in enumerate(model.loss_):
    print(f'epoch {epoch}/{len(model.loss_)} - loss: {loss} - val_loss: {model.val_loss_[epoch]}')

# model.display_train()
# Out:
# 1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 11>()
#       8 y_test = model.predict(X)
#      10 print(accuracy_score(y_test, y))
# ---> 11 for epoch, loss, val_loss in enumerate(model.loss_, model.val_loss_):
#      12     print(f'epoch {epoch}/{len(model.loss_)} - loss: {loss} - val_loss: {val_loss}')
#
# TypeError: 'list' object cannot be interpreted as an integer
